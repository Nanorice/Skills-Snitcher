# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# URL = 'https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10'
URL = 'https://www.indeed.co.uk/jobs?q=quantitative+analyst+%C2%A340,000&l=London'
#conducting a request of the stated URL above:
page = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, 'html.parser')
#printing soup in a more structured tree format that makes for easier reading
# print(soup.prettify())

# %%
def extract_salary(soup):
    salaries = []
    for div in soup.find_all(name = 'div', attrs = {'class':'row'}):
        try:
            salaries.append(div.find('nobr').text)
        except:
            try:
                div_two = div.find(name = 'div', attrs = {'class':'sjcl'})
                div_three = div_two.find('div')
                salaries.append(div_three.text.strip())
#                 print(div_three)
            except:
                salaries.append('Nothing_found')    
    return(salaries)

def extract_summary(soup):
    summaries = []
    divs = soup.find_all('div', attrs = {'class':'summary'})
#     print(divs)
    for i, div in enumerate(divs):
#         print(i, div.text)
        summaries.append(div.text.strip())
    return(summaries)

def extract_location(soup):
    locations = []
    spans = soup.find_all('span', attrs={'class':'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)

def extract_company(soup):
    companies = []
    for div in soup.find_all(name = 'div', attrs = {'class':'row'}):
        company = div.find_all(name = 'span', attrs = {'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
            else:
                sec_try = div.find_all(name = 'span', attrs = {'class':'result-link-source'})
                for span in sec_try:
                    companies.append(span.text.strip())
    return(companies)

def extract_job_title(soup):
    jobs = []
    for div in soup.find_all(name='div', attrs = {'class':'row'}):
        for a in div.find_all(name = 'a', attrs = {'data-tn-element':"jobTitle"}):
            jobs.append(a['title'])
    return(jobs)

URL = 'https://www.indeed.co.uk/jobs?q=quantitative+analyst+%C2%A340,000&l=London'
page = requests.get(URL)
soup = BeautifulSoup(page.text, 'html.parser')

title = extract_job_title(soup)

company = extract_company(soup)

ls = extract_location(soup)

summary = extract_summary(soup)
    
salary = extract_salary(soup)

df1 = zip(company, title, ls, salary, summary)
df = pd.DataFrame(df1, columns = ['company', "title", 'location', 'salary', 'summary'])
df.head()

# %%
## fetching metadata
max_jobs_to_fetch = 1000
columns = ['location', 'company_name', 'job_title', 'summary']
# columns = ['company', 'title']
df = pd.DataFrame(columns = columns)

for start in range(0, max_jobs_to_fetch, 10):
    try:
        url = 'https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start='
        page = requests.get(url + str(start))
        print('retriving url: ', (url + str(start)))
    except:
        print('---Failed to retrieve---')
        print('url:', (url + str(start)))
        continue
    soup = BeautifulSoup(page.text, 'html.parser')
    # extract info from class:row
    # company name and job title
    companies, jobs = [], []
    for div in soup.find_all(name = 'div', attrs = {'class':'row'}):
        company = div.find_all(name = 'span', attrs = {'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
            else:
                sec_try = div.find_all(name = 'span', attrs = {'class':'result-link-source'})
                for span in sec_try:
                    companies.append(span.text.strip())
        for a in div.find_all(name = 'a', attrs = {'data-tn-element':"jobTitle"}):
            jobs.append(a['title'])
            
    # extract location
    locations = []
    spans = soup.find_all('span', attrs={'class':'location'})
    for span in spans:
        locations.append(span.text)
        
    # extract summaries
    summaries = []
    divs = soup.find_all('div', attrs = {'class':'summary'})
    for i, div in enumerate(divs):
        summaries.append(div.text.strip())
        
    df_temp = zip(locations, companies, jobs, summaries)
    df_temp = pd.DataFrame(df_temp, columns = columns)
    df = df.append(df_temp).reset_index(drop = True)
    
df.to_csv('sample_data.csv', encoding='utf-8')
# Out:
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=0
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=10
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=20
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=30
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=40
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=50
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=60
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=70
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=80
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=90
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=100
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=110
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=120
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=130
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=140
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=150
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=160
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=170
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=180
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=190
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=200
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=210
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=220
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=230
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=240
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=250
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=260
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=270
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=280
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=290
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=300
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=310
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=320
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=330
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=340
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=350
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=360
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=370
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=380
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=390
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=400
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=410
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=420
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=430
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=440
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=450
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=460
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=470
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=480
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=490
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=500
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=510
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=520
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=530
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=540
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=550
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=560
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=570
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=580
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=590
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=600
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=610
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=620
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=630
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=640
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=650
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=660
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=670
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=680
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=690
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=700
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=710
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=720
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=730
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=740
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=750
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=760
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=770
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=780
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=790
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=800
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=810
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=820
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=830
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=840
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=850
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=860
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=870
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=880
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=890
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=900
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=910
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=920
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=930
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=940
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=950
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=960
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=970
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=980
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=990

# %%
max_jobs_to_fetch = 1000
columns = ['location', 'company_name', 'job_title', 'summary', 'full_info']
# columns = ['company', 'title']
df = pd.DataFrame(columns = columns)

for start in range(0, max_jobs_to_fetch, 10):
    try:
        url = 'https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=' + str(start)
        page = requests.get(url)
        print('retriving url: ', url)
    except:
        print('---Failed to retrieve---')
        print('url:', url)
        continue
    soup = BeautifulSoup(page.text, 'html.parser')
    time.sleep(1)
    ## metadata from mainpage
    
    # extract info from class:row
    # company name and job title
    companies, jobs = [], []
    for div in soup.find_all(name = 'div', attrs = {'class':'row'}):
        company = div.find_all(name = 'span', attrs = {'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
            else:
                sec_try = div.find_all(name = 'span', attrs = {'class':'result-link-source'})
                for span in sec_try:
                    companies.append(span.text.strip())
        for a in div.find_all(name = 'a', attrs = {'data-tn-element':"jobTitle"}):
            jobs.append(a['title'])
            
    # extract location
    locations = []
    spans = soup.find_all('span', attrs={'class':'location'})
    for span in spans:
        locations.append(span.text)
        
    # extract summaries
    summaries = []
    divs = soup.find_all('div', attrs = {'class':'summary'})
    for i, div in enumerate(divs):
        summaries.append(div.text.strip())
    
    ## crawl to subpages
    descriptions = []
    for adlink in soup.select('a[onmousedown*="return rclk(this,jobmap["]'):
        suburl = "https://www.indeed.com" + adlink['href']
        try:
            subpage = requests.get(suburl)
            subsoup = BeautifulSoup(subpage.text)
        except:
            print('--- Failed to retrieve sub-URL ---')
            print('url: ', suburl)
        # extract descriptions
        for des in subsoup.select('div[class*="jobsearch-JobComponent-description"]'): 
             descriptions.append(des.get_text())
            
    df_temp = zip(locations, companies, jobs, summaries, descriptions)
    df_temp = pd.DataFrame(df_temp, columns = columns)
    df = df.append(df_temp).reset_index(drop = True)
# Out:
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=0
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=10
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=20
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=30
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=40
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=50
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=60
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=70
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=80
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=90
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=100
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=110
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=120
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=130
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=140
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=150
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=160
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=170
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=180
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=190
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=200
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=210
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=220
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=230
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=240
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=250
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=260
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=270
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=280
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=290
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=300
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=310
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=320
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=330
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=340
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=350
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=360
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=370
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=380
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=390
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=400
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=410
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=420
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=430
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=440
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=450
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=460
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=470
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=480
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=490
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=500
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=510
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=520
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=530
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=540
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=550
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=560
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=570
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=580
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=590
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=600
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=610
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=620
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=630
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=640
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=650
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=660
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=670
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=680
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=690
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=700
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=710
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=720
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=730
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=740
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=750
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=760
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=770
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=780
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=790
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=800
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=810
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=820
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=830
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=840
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=850
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=860
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=870
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=880
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=890
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=900
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=910
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=920
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=930
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=940
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=950
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=960
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=970
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=980
# retriving url:  https://www.indeed.co.uk/jobs?q=finance&l=London&radius=25&start=990

# %%
df.to_csv('sample_full.csv', encoding = 'utf-8')
