# %% [markdown]
# # Analysis of 220k Monster job postings
#
#  - data used is from Kaggle
#  - uses skills-ml pipeline
#  - trains embedding model
#  - trains occupation classifier

# %% [markdown]
# # House-keeping

# %%
# general
import os
import json
import copy
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import logging
from retrying import Retrying
from io import BytesIO
from itertools import chain, islice
from typing import Dict, Text, Any, Generator
import pickle

# common schema
from skills_ml.job_postings.raw.virginia import VirginiaTransformer

# embedding
from skills_ml.algorithms.embedding.models import Word2VecModel, FastTextModel
from skills_ml.job_postings.corpora import Word2VecGensimCorpusCreator, Doc2VecGensimCorpusCreator
from skills_ml.algorithms.preprocessing import IterablePipeline
from skills_ml.algorithms import nlp
from functools import partial
from skills_ml.algorithms.embedding.train import EmbeddingTrainer

# occupation classifier
from skills_ml.storage import FSStore, open_sesame
from skills_ml.ontologies.onet import Onet
from skills_ml.algorithms.occupation_classifiers import FullSOC, SOCMajorGroup
from skills_ml.utils import itershuffle
from skills_ml.algorithms.occupation_classifiers import DesignMatrix
from skills_ml.algorithms.occupation_classifiers.train import OccupationClassifierTrainer
from skills_ml.algorithms.occupation_classifiers.test import OccupationClassifierTester
from skills_ml.evaluation.occ_cls_evaluator import OnetOccupationClassificationEvaluator
from skills_ml.algorithms.occupation_classifiers.classifiers import CombinedClassifier
from skills_ml.algorithms.embedding.train import Reiterable
from skills_ml.job_postings.corpora import SimpleCorpusCreator
from skills_ml.job_postings.corpora import Doc2VecGensimCorpusCreator, CorpusCreator

# skill extraction
from skills_ml.algorithms.skill_extractors import SkillEndingPatternExtractor
from skills_ml.job_postings.common_schema import JobPostingCollectionSample
from skills_ml.algorithms.skill_extractors import ExactMatchSkillExtractor
from skills_ml.algorithms.skill_extractors import SocScopedExactMatchSkillExtractor
# Out:
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/oren/opt/anaconda3/envs/skills_ml/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Load job posting data

# %%
file_name = 'indeed_finance_energy.csv' 
monster_220k = pd.read_csv(file_name).reset_index(drop=True)
monster_220k.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization  \
# 0                              NaN
# 1          Printing and Publishing
# 2  Personal and Household Services
# 3                 Altec Industries
# 4                           Retail
#
#                                             page_url salary  \
# 0  http://jobview.monster.com/it-support-technici...    NaN
# 1  http://jobview.monster.com/business-reporter-e...    NaN
# 2  http://jobview.monster.com/senior-training-lea...    NaN
# 3  http://jobview.monster.com/engineer-quality-jo...    NaN
# 4  http://jobview.monster.com/shift-supervisor-pa...    NaN
#
#                        sector                           uniq_id
# 0     IT/Software Development  11d599f229a80023d2f40e7c52cd941e
# 1                         NaN  e4cbb126dabf22159aff90223243ff2a
# 2                         NaN  839106b353877fa3d896ffb9c1fe01c0
# 3   Experienced (Non-Manager)  58435fcab804439efdcaa7ecca0fd783
# 4  Project/Program Management  64d0272dc8496abfd9523a8df63c184c

# %% [markdown]
# # Parse into job posting schema

# %%
fname = '50_sample.json'
f = open(fname, 'r')
data = f.read().split('\n')[0]
schema = json.loads(data)
s50 = f.read().split('\n')[0:50]

# %%
df_json = []
for i in range(monster_220k.shape[0]):
    occupation = copy.deepcopy(schema)
    occupation['hiringOrganization']['location'] = monster_220k['location'][i]
    occupation['title'] = monster_220k['job_title'][i]
    occupation['jobDescription'] = monster_220k['job_description'][i].split('\n')
    df_json.append(occupation)

# %%
with open("monster_220k.json", "w") as write_file:
    for i in df_json:
        json.dump(i, write_file)
        write_file.write('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f95bfce52bd> in <module>
#       1 with open("monster_220k.json", "w") as write_file:
# ----> 2     for i in df_json:
#       3         json.dump(i, write_file)
#       4         write_file.write('\n')
#
# NameError: name 'df_json' is not defined

# %%
## reads json data file

JobPostingType = Dict[Text, Any]
JobPostingGeneratorType = Generator[JobPostingType, None, None]
MetadataType = Dict[Text, Dict[Text, Any]]

class monsterParser(object):
    def __init__(self):
        fname = 'monster_220k.json'
        f = open(fname, 'r')
        self.lines = f.read().split('\n')
        self.transformer = VirginiaTransformer(partner_id = 'VA')
        
    def __iter__(self) -> JobPostingGeneratorType:
        for line in self.lines:
            if line:
                yield self.transformer._transform(json.loads(line))
    
    @property
    def metadata(self) -> MetadataType:
        return {'job postings': {
            'downloaded_from': 'jobs.monster.com',
            'month': '2020-08',
            'purpose': 'monster_analysis'
        }}

# %%
job_postings = monsterParser()

# %% [markdown]
# # Embedding model

# %%
cbow = Word2VecModel(size=200, sg=0, window=7, iter=3, batch_words=1000)
skip_gram = Word2VecModel(size=200, sg=1, window=7, iter=3, batch_words=1000)
fasttext = FastTextModel(size=200, window=7, iter=3, batch_words=1000) 

w2v_corpus_generator = Word2VecGensimCorpusCreator(job_postings)

# %%
trainer = EmbeddingTrainer(cbow, skip_gram, fasttext, batch_size=100)
trainer.train(w2v_corpus_generator)
# Out:
# 2020-08-02 00:47:41,277 : INFO : Training batch #0
# 2020-08-02 00:47:41,278 : INFO : collecting all words and their counts
# 2020-08-02 00:47:41,279 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:41,281 : INFO : collected 879 word types from a corpus of 14733 raw words and 100 sentences
# 2020-08-02 00:47:41,282 : INFO : Loading a fresh vocabulary
# 2020-08-02 00:47:41,283 : INFO : effective_min_count=5 retains 169 unique words (19% of original 879, drops 710)
# 2020-08-02 00:47:41,284 : INFO : effective_min_count=5 leaves 13666 word corpus (92% of original 14733, drops 1067)
# 2020-08-02 00:47:41,286 : INFO : deleting the raw counts dictionary of 879 items
# 2020-08-02 00:47:41,287 : INFO : sample=0.001 downsamples 87 most-common words
# 2020-08-02 00:47:41,287 : INFO : downsampling leaves estimated 5581 word corpus (40.8% of prior 13666)
# 2020-08-02 00:47:41,289 : INFO : estimated required memory for 169 words and 200 dimensions: 354900 bytes
# 2020-08-02 00:47:41,290 : INFO : resetting layer weights
# 2020-08-02 00:47:41,301 : INFO : training model with 3 workers on 169 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:41,313 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,314 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,319 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,320 : INFO : EPOCH - 1 : training on 14733 raw words (5556 effective words) took 0.0s, 391581 effective words/s
# 2020-08-02 00:47:41,332 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,335 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,336 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,336 : INFO : EPOCH - 2 : training on 14733 raw words (5557 effective words) took 0.0s, 474751 effective words/s
# 2020-08-02 00:47:41,349 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,350 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,351 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,352 : INFO : EPOCH - 3 : training on 14733 raw words (5588 effective words) took 0.0s, 553857 effective words/s
# 2020-08-02 00:47:41,353 : INFO : training on a 44199 raw words (16701 effective words) took 0.1s, 328673 effective words/s
# 2020-08-02 00:47:41,354 : INFO : collecting all words and their counts
# 2020-08-02 00:47:41,354 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:41,357 : INFO : collected 879 word types from a corpus of 14733 raw words and 100 sentences
# 2020-08-02 00:47:41,359 : INFO : Loading a fresh vocabulary
# 2020-08-02 00:47:41,360 : INFO : effective_min_count=5 retains 169 unique words (19% of original 879, drops 710)
# 2020-08-02 00:47:41,361 : INFO : effective_min_count=5 leaves 13666 word corpus (92% of original 14733, drops 1067)
# 2020-08-02 00:47:41,363 : INFO : deleting the raw counts dictionary of 879 items
# 2020-08-02 00:47:41,364 : INFO : sample=0.001 downsamples 87 most-common words
# 2020-08-02 00:47:41,366 : INFO : downsampling leaves estimated 5581 word corpus (40.8% of prior 13666)
# 2020-08-02 00:47:41,368 : INFO : estimated required memory for 169 words and 200 dimensions: 354900 bytes
# 2020-08-02 00:47:41,369 : INFO : resetting layer weights
# 2020-08-02 00:47:41,386 : INFO : training model with 3 workers on 169 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:41,418 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,421 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,422 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,423 : INFO : EPOCH - 1 : training on 14733 raw words (5556 effective words) took 0.0s, 178931 effective words/s
# 2020-08-02 00:47:41,447 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,448 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,450 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,451 : INFO : EPOCH - 2 : training on 14733 raw words (5557 effective words) took 0.0s, 255679 effective words/s
# 2020-08-02 00:47:41,476 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:41,477 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:41,478 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:41,479 : INFO : EPOCH - 3 : training on 14733 raw words (5557 effective words) took 0.0s, 241354 effective words/s
# 2020-08-02 00:47:41,480 : INFO : training on a 44199 raw words (16670 effective words) took 0.1s, 183421 effective words/s
# 2020-08-02 00:47:41,481 : INFO : collecting all words and their counts
# 2020-08-02 00:47:41,482 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:41,486 : INFO : collected 879 word types from a corpus of 14733 raw words and 100 sentences
# 2020-08-02 00:47:41,487 : INFO : Loading a fresh vocabulary
# 2020-08-02 00:47:41,489 : INFO : effective_min_count=5 retains 169 unique words (19% of original 879, drops 710)
# 2020-08-02 00:47:41,490 : INFO : effective_min_count=5 leaves 13666 word corpus (92% of original 14733, drops 1067)
# 2020-08-02 00:47:41,491 : INFO : deleting the raw counts dictionary of 879 items
# 2020-08-02 00:47:41,492 : INFO : sample=0.001 downsamples 87 most-common words
# 2020-08-02 00:47:41,493 : INFO : downsampling leaves estimated 5581 word corpus (40.8% of prior 13666)
# 2020-08-02 00:47:41,496 : INFO : estimated required memory for 169 words, 2772 buckets and 200 dimensions: 2610020 bytes
# 2020-08-02 00:47:41,498 : INFO : resetting layer weights
# 2020-08-02 00:47:43,034 : INFO : Total number of ngrams is 2772
# 2020-08-02 00:47:43,214 : INFO : training model with 3 workers on 169 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:43,244 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,246 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,248 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,249 : INFO : EPOCH - 1 : training on 14733 raw words (5635 effective words) took 0.0s, 174948 effective words/s
# 2020-08-02 00:47:43,279 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,281 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,282 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,283 : INFO : EPOCH - 2 : training on 14733 raw words (5534 effective words) took 0.0s, 177712 effective words/s
# 2020-08-02 00:47:43,316 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,317 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,320 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,321 : INFO : EPOCH - 3 : training on 14733 raw words (5642 effective words) took 0.0s, 164081 effective words/s
# 2020-08-02 00:47:43,322 : INFO : training on a 44199 raw words (16811 effective words) took 0.1s, 157177 effective words/s
# 2020-08-02 00:47:43,448 : INFO : Training batch #1
# 2020-08-02 00:47:43,451 : INFO : collecting all words and their counts
# 2020-08-02 00:47:43,452 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:43,455 : INFO : collected 937 word types from a corpus of 14967 raw words and 100 sentences
# 2020-08-02 00:47:43,456 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:43,457 : INFO : New added 187 unique words (16% of original 1124) and increased the count of 187 pre-existing words (16% of original 1124)
# 2020-08-02 00:47:43,459 : INFO : deleting the raw counts dictionary of 937 items
# 2020-08-02 00:47:43,460 : INFO : sample=0.001 downsamples 172 most-common words
# 2020-08-02 00:47:43,461 : INFO : downsampling leaves estimated 11515 word corpus (83.5% of prior 13783)
# 2020-08-02 00:47:43,462 : INFO : estimated required memory for 374 words and 200 dimensions: 785400 bytes
# 2020-08-02 00:47:43,463 : INFO : updating layer weights
# 2020-08-02 00:47:43,473 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:43,474 : INFO : training model with 3 workers on 240 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:43,487 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,488 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,489 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,491 : INFO : EPOCH - 1 : training on 14967 raw words (5874 effective words) took 0.0s, 521704 effective words/s
# 2020-08-02 00:47:43,504 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,505 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,505 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,506 : INFO : EPOCH - 2 : training on 14967 raw words (5827 effective words) took 0.0s, 626422 effective words/s
# 2020-08-02 00:47:43,518 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,519 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,520 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,521 : INFO : EPOCH - 3 : training on 14967 raw words (5855 effective words) took 0.0s, 585253 effective words/s
# 2020-08-02 00:47:43,522 : INFO : training on a 44901 raw words (17556 effective words) took 0.0s, 369866 effective words/s
# 2020-08-02 00:47:43,523 : INFO : collecting all words and their counts
# 2020-08-02 00:47:43,523 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:43,528 : INFO : collected 937 word types from a corpus of 14967 raw words and 100 sentences
# 2020-08-02 00:47:43,531 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:43,532 : INFO : New added 187 unique words (16% of original 1124) and increased the count of 187 pre-existing words (16% of original 1124)
# 2020-08-02 00:47:43,534 : INFO : deleting the raw counts dictionary of 937 items
# 2020-08-02 00:47:43,535 : INFO : sample=0.001 downsamples 172 most-common words
# 2020-08-02 00:47:43,536 : INFO : downsampling leaves estimated 11515 word corpus (83.5% of prior 13783)
# 2020-08-02 00:47:43,537 : INFO : estimated required memory for 374 words and 200 dimensions: 785400 bytes
# 2020-08-02 00:47:43,538 : INFO : updating layer weights
# 2020-08-02 00:47:43,550 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:43,551 : INFO : training model with 3 workers on 240 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:43,580 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,582 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,582 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,583 : INFO : EPOCH - 1 : training on 14967 raw words (5800 effective words) took 0.0s, 205041 effective words/s
# 2020-08-02 00:47:43,608 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,609 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,610 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,611 : INFO : EPOCH - 2 : training on 14967 raw words (5847 effective words) took 0.0s, 244988 effective words/s
# 2020-08-02 00:47:43,636 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,638 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,639 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,639 : INFO : EPOCH - 3 : training on 14967 raw words (5789 effective words) took 0.0s, 270300 effective words/s
# 2020-08-02 00:47:43,640 : INFO : training on a 44901 raw words (17436 effective words) took 0.1s, 197665 effective words/s
# 2020-08-02 00:47:43,641 : INFO : collecting all words and their counts
# 2020-08-02 00:47:43,641 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:43,644 : INFO : collected 937 word types from a corpus of 14967 raw words and 100 sentences
# 2020-08-02 00:47:43,645 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:43,646 : INFO : New added 187 unique words (16% of original 1124) and increased the count of 187 pre-existing words (16% of original 1124)
# 2020-08-02 00:47:43,648 : INFO : deleting the raw counts dictionary of 937 items
# 2020-08-02 00:47:43,649 : INFO : sample=0.001 downsamples 172 most-common words
# 2020-08-02 00:47:43,650 : INFO : downsampling leaves estimated 11515 word corpus (83.5% of prior 13783)
# 2020-08-02 00:47:43,653 : INFO : estimated required memory for 240 words, 3727 buckets and 200 dimensions: 3540272 bytes
# 2020-08-02 00:47:43,654 : INFO : updating layer weights
# 2020-08-02 00:47:43,667 : INFO : Number of new ngrams is 955
# 2020-08-02 00:47:43,682 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:43,683 : INFO : training model with 3 workers on 240 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:43,715 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,716 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,718 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,719 : INFO : EPOCH - 1 : training on 14967 raw words (5831 effective words) took 0.0s, 178195 effective words/s
# 2020-08-02 00:47:43,750 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,751 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,753 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,754 : INFO : EPOCH - 2 : training on 14967 raw words (5880 effective words) took 0.0s, 185566 effective words/s
# 2020-08-02 00:47:43,785 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,786 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,788 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,788 : INFO : EPOCH - 3 : training on 14967 raw words (5793 effective words) took 0.0s, 197804 effective words/s
# 2020-08-02 00:47:43,789 : INFO : training on a 44901 raw words (17504 effective words) took 0.1s, 165714 effective words/s
# 2020-08-02 00:47:43,907 : INFO : Training batch #2
# 2020-08-02 00:47:43,907 : INFO : collecting all words and their counts
# 2020-08-02 00:47:43,909 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:43,913 : INFO : collected 977 word types from a corpus of 15234 raw words and 100 sentences
# 2020-08-02 00:47:43,914 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:43,915 : INFO : New added 195 unique words (16% of original 1172) and increased the count of 195 pre-existing words (16% of original 1172)
# 2020-08-02 00:47:43,918 : INFO : deleting the raw counts dictionary of 977 items
# 2020-08-02 00:47:43,919 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:43,920 : INFO : downsampling leaves estimated 11817 word corpus (84.2% of prior 14037)
# 2020-08-02 00:47:43,922 : INFO : estimated required memory for 390 words and 200 dimensions: 819000 bytes
# 2020-08-02 00:47:43,923 : INFO : updating layer weights
# 2020-08-02 00:47:43,930 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:43,931 : INFO : training model with 3 workers on 294 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:43,940 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,941 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,941 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,942 : INFO : EPOCH - 1 : training on 15234 raw words (5918 effective words) took 0.0s, 695627 effective words/s
# 2020-08-02 00:47:43,953 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,953 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,954 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,955 : INFO : EPOCH - 2 : training on 15234 raw words (6019 effective words) took 0.0s, 724396 effective words/s
# 2020-08-02 00:47:43,966 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:43,967 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:43,968 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:43,968 : INFO : EPOCH - 3 : training on 15234 raw words (6115 effective words) took 0.0s, 808425 effective words/s
# 2020-08-02 00:47:43,969 : INFO : training on a 45702 raw words (18052 effective words) took 0.0s, 484209 effective words/s
# 2020-08-02 00:47:43,969 : INFO : collecting all words and their counts
# 2020-08-02 00:47:43,970 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:43,972 : INFO : collected 977 word types from a corpus of 15234 raw words and 100 sentences
# 2020-08-02 00:47:43,973 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:43,975 : INFO : New added 195 unique words (16% of original 1172) and increased the count of 195 pre-existing words (16% of original 1172)
# 2020-08-02 00:47:43,977 : INFO : deleting the raw counts dictionary of 977 items
# 2020-08-02 00:47:43,978 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:43,979 : INFO : downsampling leaves estimated 11817 word corpus (84.2% of prior 14037)
# 2020-08-02 00:47:43,980 : INFO : estimated required memory for 390 words and 200 dimensions: 819000 bytes
# 2020-08-02 00:47:43,981 : INFO : updating layer weights
# 2020-08-02 00:47:43,989 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:43,990 : INFO : training model with 3 workers on 294 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,012 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,013 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,015 : INFO : EPOCH - 1 : training on 15234 raw words (6032 effective words) took 0.0s, 298173 effective words/s
# 2020-08-02 00:47:44,038 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,039 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,040 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,041 : INFO : EPOCH - 2 : training on 15234 raw words (5977 effective words) took 0.0s, 276092 effective words/s
# 2020-08-02 00:47:44,064 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,066 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,067 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,068 : INFO : EPOCH - 3 : training on 15234 raw words (6063 effective words) took 0.0s, 270326 effective words/s
# 2020-08-02 00:47:44,068 : INFO : training on a 45702 raw words (18072 effective words) took 0.1s, 231692 effective words/s
# 2020-08-02 00:47:44,069 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,070 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,072 : INFO : collected 977 word types from a corpus of 15234 raw words and 100 sentences
# 2020-08-02 00:47:44,073 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,074 : INFO : New added 195 unique words (16% of original 1172) and increased the count of 195 pre-existing words (16% of original 1172)
# 2020-08-02 00:47:44,076 : INFO : deleting the raw counts dictionary of 977 items
# 2020-08-02 00:47:44,077 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:44,078 : INFO : downsampling leaves estimated 11817 word corpus (84.2% of prior 14037)
# 2020-08-02 00:47:44,082 : INFO : estimated required memory for 294 words, 4462 buckets and 200 dimensions: 4254632 bytes
# 2020-08-02 00:47:44,083 : INFO : updating layer weights
# 2020-08-02 00:47:44,097 : INFO : Number of new ngrams is 735
# 2020-08-02 00:47:44,109 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,110 : INFO : training model with 3 workers on 294 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,140 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,141 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,143 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,144 : INFO : EPOCH - 1 : training on 15234 raw words (5924 effective words) took 0.0s, 191156 effective words/s
# 2020-08-02 00:47:44,182 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,183 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,185 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,186 : INFO : EPOCH - 2 : training on 15234 raw words (6007 effective words) took 0.0s, 160240 effective words/s
# 2020-08-02 00:47:44,221 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,223 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,224 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,224 : INFO : EPOCH - 3 : training on 15234 raw words (6096 effective words) took 0.0s, 175542 effective words/s
# 2020-08-02 00:47:44,225 : INFO : training on a 45702 raw words (18027 effective words) took 0.1s, 157794 effective words/s
# 2020-08-02 00:47:44,351 : INFO : Training batch #3
# 2020-08-02 00:47:44,352 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,352 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,355 : INFO : collected 940 word types from a corpus of 15311 raw words and 100 sentences
# 2020-08-02 00:47:44,355 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,356 : INFO : New added 177 unique words (15% of original 1117) and increased the count of 177 pre-existing words (15% of original 1117)
# 2020-08-02 00:47:44,358 : INFO : deleting the raw counts dictionary of 940 items
# 2020-08-02 00:47:44,359 : INFO : sample=0.001 downsamples 180 most-common words
# 2020-08-02 00:47:44,360 : INFO : downsampling leaves estimated 12061 word corpus (85.0% of prior 14187)
# 2020-08-02 00:47:44,361 : INFO : estimated required memory for 354 words and 200 dimensions: 743400 bytes
# 2020-08-02 00:47:44,361 : INFO : updating layer weights
# 2020-08-02 00:47:44,368 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,369 : INFO : training model with 3 workers on 343 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,379 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,380 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,380 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,381 : INFO : EPOCH - 1 : training on 15311 raw words (6132 effective words) took 0.0s, 642417 effective words/s
# 2020-08-02 00:47:44,392 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,393 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,394 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,395 : INFO : EPOCH - 2 : training on 15311 raw words (6153 effective words) took 0.0s, 667219 effective words/s
# 2020-08-02 00:47:44,407 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,408 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,409 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,409 : INFO : EPOCH - 3 : training on 15311 raw words (6159 effective words) took 0.0s, 830249 effective words/s
# 2020-08-02 00:47:44,410 : INFO : training on a 45933 raw words (18444 effective words) took 0.0s, 451795 effective words/s
# 2020-08-02 00:47:44,412 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,413 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,415 : INFO : collected 940 word types from a corpus of 15311 raw words and 100 sentences
# 2020-08-02 00:47:44,416 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,417 : INFO : New added 177 unique words (15% of original 1117) and increased the count of 177 pre-existing words (15% of original 1117)
# 2020-08-02 00:47:44,419 : INFO : deleting the raw counts dictionary of 940 items
# 2020-08-02 00:47:44,420 : INFO : sample=0.001 downsamples 180 most-common words
# 2020-08-02 00:47:44,421 : INFO : downsampling leaves estimated 12061 word corpus (85.0% of prior 14187)
# 2020-08-02 00:47:44,422 : INFO : estimated required memory for 354 words and 200 dimensions: 743400 bytes
# 2020-08-02 00:47:44,423 : INFO : updating layer weights
# 2020-08-02 00:47:44,429 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,431 : INFO : training model with 3 workers on 343 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,456 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,457 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,458 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,458 : INFO : EPOCH - 1 : training on 15311 raw words (6238 effective words) took 0.0s, 285895 effective words/s
# 2020-08-02 00:47:44,483 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,485 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,485 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,486 : INFO : EPOCH - 2 : training on 15311 raw words (6205 effective words) took 0.0s, 279110 effective words/s
# 2020-08-02 00:47:44,533 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,535 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,536 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,536 : INFO : EPOCH - 3 : training on 15311 raw words (6209 effective words) took 0.0s, 137953 effective words/s
# 2020-08-02 00:47:44,537 : INFO : training on a 45933 raw words (18652 effective words) took 0.1s, 176348 effective words/s
# 2020-08-02 00:47:44,538 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,538 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,541 : INFO : collected 940 word types from a corpus of 15311 raw words and 100 sentences
# 2020-08-02 00:47:44,541 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,543 : INFO : New added 177 unique words (15% of original 1117) and increased the count of 177 pre-existing words (15% of original 1117)
# 2020-08-02 00:47:44,545 : INFO : deleting the raw counts dictionary of 940 items
# 2020-08-02 00:47:44,546 : INFO : sample=0.001 downsamples 180 most-common words
# 2020-08-02 00:47:44,546 : INFO : downsampling leaves estimated 12061 word corpus (85.0% of prior 14187)
# 2020-08-02 00:47:44,551 : INFO : estimated required memory for 343 words, 5076 buckets and 200 dimensions: 4860676 bytes
# 2020-08-02 00:47:44,553 : INFO : updating layer weights
# 2020-08-02 00:47:44,568 : INFO : Number of new ngrams is 614
# 2020-08-02 00:47:44,582 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,583 : INFO : training model with 3 workers on 343 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,615 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,617 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,617 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,618 : INFO : EPOCH - 1 : training on 15311 raw words (6249 effective words) took 0.0s, 206112 effective words/s
# 2020-08-02 00:47:44,652 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,653 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,654 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,655 : INFO : EPOCH - 2 : training on 15311 raw words (6171 effective words) took 0.0s, 187360 effective words/s
# 2020-08-02 00:47:44,687 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,688 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,689 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,690 : INFO : EPOCH - 3 : training on 15311 raw words (6219 effective words) took 0.0s, 201703 effective words/s
# 2020-08-02 00:47:44,691 : INFO : training on a 45933 raw words (18639 effective words) took 0.1s, 174034 effective words/s
# 2020-08-02 00:47:44,804 : INFO : Training batch #4
# 2020-08-02 00:47:44,804 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,805 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,808 : INFO : collected 853 word types from a corpus of 14317 raw words and 100 sentences
# 2020-08-02 00:47:44,808 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,809 : INFO : New added 158 unique words (15% of original 1011) and increased the count of 158 pre-existing words (15% of original 1011)
# 2020-08-02 00:47:44,811 : INFO : deleting the raw counts dictionary of 853 items
# 2020-08-02 00:47:44,812 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:44,813 : INFO : downsampling leaves estimated 10720 word corpus (80.4% of prior 13331)
# 2020-08-02 00:47:44,814 : INFO : estimated required memory for 316 words and 200 dimensions: 663600 bytes
# 2020-08-02 00:47:44,814 : INFO : updating layer weights
# 2020-08-02 00:47:44,821 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,822 : INFO : training model with 3 workers on 381 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,833 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,834 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,834 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,835 : INFO : EPOCH - 1 : training on 14317 raw words (5494 effective words) took 0.0s, 611123 effective words/s
# 2020-08-02 00:47:44,846 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,847 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,847 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,848 : INFO : EPOCH - 2 : training on 14317 raw words (5503 effective words) took 0.0s, 604771 effective words/s
# 2020-08-02 00:47:44,858 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,860 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,860 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,861 : INFO : EPOCH - 3 : training on 14317 raw words (5555 effective words) took 0.0s, 657004 effective words/s
# 2020-08-02 00:47:44,862 : INFO : training on a 42951 raw words (16552 effective words) took 0.0s, 421475 effective words/s
# 2020-08-02 00:47:44,862 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,863 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,865 : INFO : collected 853 word types from a corpus of 14317 raw words and 100 sentences
# 2020-08-02 00:47:44,866 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,867 : INFO : New added 158 unique words (15% of original 1011) and increased the count of 158 pre-existing words (15% of original 1011)
# 2020-08-02 00:47:44,869 : INFO : deleting the raw counts dictionary of 853 items
# 2020-08-02 00:47:44,870 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:44,870 : INFO : downsampling leaves estimated 10720 word corpus (80.4% of prior 13331)
# 2020-08-02 00:47:44,872 : INFO : estimated required memory for 316 words and 200 dimensions: 663600 bytes
# 2020-08-02 00:47:44,872 : INFO : updating layer weights
# 2020-08-02 00:47:44,879 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:44,879 : INFO : training model with 3 workers on 381 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:44,901 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,902 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,903 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,903 : INFO : EPOCH - 1 : training on 14317 raw words (5516 effective words) took 0.0s, 293003 effective words/s
# 2020-08-02 00:47:44,925 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,927 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,928 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,929 : INFO : EPOCH - 2 : training on 14317 raw words (5559 effective words) took 0.0s, 256079 effective words/s
# 2020-08-02 00:47:44,951 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:44,952 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:44,953 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:44,953 : INFO : EPOCH - 3 : training on 14317 raw words (5575 effective words) took 0.0s, 273716 effective words/s
# 2020-08-02 00:47:44,954 : INFO : training on a 42951 raw words (16650 effective words) took 0.1s, 225680 effective words/s
# 2020-08-02 00:47:44,955 : INFO : collecting all words and their counts
# 2020-08-02 00:47:44,956 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:44,958 : INFO : collected 853 word types from a corpus of 14317 raw words and 100 sentences
# 2020-08-02 00:47:44,960 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:44,962 : INFO : New added 158 unique words (15% of original 1011) and increased the count of 158 pre-existing words (15% of original 1011)
# 2020-08-02 00:47:44,967 : INFO : deleting the raw counts dictionary of 853 items
# 2020-08-02 00:47:44,968 : INFO : sample=0.001 downsamples 166 most-common words
# 2020-08-02 00:47:44,970 : INFO : downsampling leaves estimated 10720 word corpus (80.4% of prior 13331)
# 2020-08-02 00:47:44,979 : INFO : estimated required memory for 381 words, 5494 buckets and 200 dimensions: 5283196 bytes
# 2020-08-02 00:47:44,981 : INFO : updating layer weights
# 2020-08-02 00:47:45,005 : INFO : Number of new ngrams is 418
# 2020-08-02 00:47:45,013 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:45,015 : INFO : training model with 3 workers on 381 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:45,077 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,079 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,081 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,083 : INFO : EPOCH - 1 : training on 14317 raw words (5570 effective words) took 0.1s, 88368 effective words/s
# 2020-08-02 00:47:45,128 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,131 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,133 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,134 : INFO : EPOCH - 2 : training on 14317 raw words (5527 effective words) took 0.0s, 123647 effective words/s
# 2020-08-02 00:47:45,179 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,181 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,182 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,183 : INFO : EPOCH - 3 : training on 14317 raw words (5425 effective words) took 0.0s, 122511 effective words/s
# 2020-08-02 00:47:45,183 : INFO : training on a 42951 raw words (16522 effective words) took 0.2s, 98514 effective words/s
# 2020-08-02 00:47:45,321 : INFO : Training batch #5
# 2020-08-02 00:47:45,321 : INFO : collecting all words and their counts
# 2020-08-02 00:47:45,322 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:45,325 : INFO : collected 987 word types from a corpus of 14814 raw words and 100 sentences
# 2020-08-02 00:47:45,326 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:45,327 : INFO : New added 183 unique words (15% of original 1170) and increased the count of 183 pre-existing words (15% of original 1170)
# 2020-08-02 00:47:45,329 : INFO : deleting the raw counts dictionary of 987 items
# 2020-08-02 00:47:45,329 : INFO : sample=0.001 downsamples 168 most-common words
# 2020-08-02 00:47:45,330 : INFO : downsampling leaves estimated 11107 word corpus (81.7% of prior 13598)
# 2020-08-02 00:47:45,331 : INFO : estimated required memory for 366 words and 200 dimensions: 768600 bytes
# 2020-08-02 00:47:45,332 : INFO : updating layer weights
# 2020-08-02 00:47:45,337 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:45,337 : INFO : training model with 3 workers on 416 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:45,353 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,354 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,354 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,355 : INFO : EPOCH - 1 : training on 14814 raw words (5757 effective words) took 0.0s, 463477 effective words/s
# 2020-08-02 00:47:45,365 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,367 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,369 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,370 : INFO : EPOCH - 2 : training on 14814 raw words (5817 effective words) took 0.0s, 550126 effective words/s
# 2020-08-02 00:47:45,382 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,383 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,384 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,385 : INFO : EPOCH - 3 : training on 14814 raw words (5801 effective words) took 0.0s, 562827 effective words/s
# 2020-08-02 00:47:45,385 : INFO : training on a 44442 raw words (17375 effective words) took 0.0s, 367340 effective words/s
# 2020-08-02 00:47:45,386 : INFO : collecting all words and their counts
# 2020-08-02 00:47:45,386 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:45,389 : INFO : collected 987 word types from a corpus of 14814 raw words and 100 sentences
# 2020-08-02 00:47:45,389 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:45,390 : INFO : New added 183 unique words (15% of original 1170) and increased the count of 183 pre-existing words (15% of original 1170)
# 2020-08-02 00:47:45,393 : INFO : deleting the raw counts dictionary of 987 items
# 2020-08-02 00:47:45,394 : INFO : sample=0.001 downsamples 168 most-common words
# 2020-08-02 00:47:45,394 : INFO : downsampling leaves estimated 11107 word corpus (81.7% of prior 13598)
# 2020-08-02 00:47:45,396 : INFO : estimated required memory for 366 words and 200 dimensions: 768600 bytes
# 2020-08-02 00:47:45,397 : INFO : updating layer weights
# 2020-08-02 00:47:45,402 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:45,403 : INFO : training model with 3 workers on 416 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:45,427 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,428 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,429 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,429 : INFO : EPOCH - 1 : training on 14814 raw words (5670 effective words) took 0.0s, 238735 effective words/s
# 2020-08-02 00:47:45,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,453 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,455 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,456 : INFO : EPOCH - 2 : training on 14814 raw words (5731 effective words) took 0.0s, 258418 effective words/s
# 2020-08-02 00:47:45,479 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,480 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,481 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,482 : INFO : EPOCH - 3 : training on 14814 raw words (5782 effective words) took 0.0s, 251090 effective words/s
# 2020-08-02 00:47:45,483 : INFO : training on a 44442 raw words (17183 effective words) took 0.1s, 216372 effective words/s
# 2020-08-02 00:47:45,483 : INFO : collecting all words and their counts
# 2020-08-02 00:47:45,484 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:45,486 : INFO : collected 987 word types from a corpus of 14814 raw words and 100 sentences
# 2020-08-02 00:47:45,487 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:45,488 : INFO : New added 183 unique words (15% of original 1170) and increased the count of 183 pre-existing words (15% of original 1170)
# 2020-08-02 00:47:45,490 : INFO : deleting the raw counts dictionary of 987 items
# 2020-08-02 00:47:45,490 : INFO : sample=0.001 downsamples 168 most-common words
# 2020-08-02 00:47:45,491 : INFO : downsampling leaves estimated 11107 word corpus (81.7% of prior 13598)
# 2020-08-02 00:47:45,496 : INFO : estimated required memory for 416 words, 5815 buckets and 200 dimensions: 5621808 bytes
# 2020-08-02 00:47:45,498 : INFO : updating layer weights
# 2020-08-02 00:47:45,512 : INFO : Number of new ngrams is 321
# 2020-08-02 00:47:45,516 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:45,517 : INFO : training model with 3 workers on 416 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:45,547 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,548 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,550 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,550 : INFO : EPOCH - 1 : training on 14814 raw words (5719 effective words) took 0.0s, 191720 effective words/s
# 2020-08-02 00:47:45,579 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,580 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,582 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,583 : INFO : EPOCH - 2 : training on 14814 raw words (5792 effective words) took 0.0s, 208748 effective words/s
# 2020-08-02 00:47:45,612 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,613 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,616 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,617 : INFO : EPOCH - 3 : training on 14814 raw words (5847 effective words) took 0.0s, 194453 effective words/s
# 2020-08-02 00:47:45,618 : INFO : training on a 44442 raw words (17358 effective words) took 0.1s, 174280 effective words/s
# 2020-08-02 00:47:45,751 : INFO : Training batch #6
# 2020-08-02 00:47:45,751 : INFO : collecting all words and their counts
# 2020-08-02 00:47:45,752 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:47:45,754 : INFO : collected 1027 word types from a corpus of 14614 raw words and 100 sentences
# 2020-08-02 00:47:45,755 : INFO : Updating model with new vocabulary
# 2020-08-02 00:47:45,756 : INFO : New added 151 unique words (12% of original 1178) and increased the count of 151 pre-existing words (12% of original 1178)
# 2020-08-02 00:47:45,758 : INFO : deleting the raw counts dictionary of 1027 items
# 2020-08-02 00:47:45,759 : INFO : sample=0.001 downsamples 168 most-common words
# 2020-08-02 00:47:45,760 : INFO : downsampling leaves estimated 10625 word corpus (79.5% of prior 13373)
# 2020-08-02 00:47:45,761 : INFO : estimated required memory for 302 words and 200 dimensions: 634200 bytes
# 2020-08-02 00:47:45,762 : INFO : updating layer weights
# 2020-08-02 00:47:45,768 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:47:45,769 : INFO : training model with 3 workers on 442 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:47:45,780 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,781 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,781 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,782 : INFO : EPOCH - 1 : training on 14614 raw words (5583 effective words) took 0.0s, 669334 effective words/s
# 2020-08-02 00:47:45,792 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:47:45,794 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:47:45,795 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:47:45,795 : INFO : EPOCH - 2 : training on 14614 raw words (5550 effective words) took 0.0s, 629645 effective words/s
# 2020-08-02 00:47:45,806 : INFO : worker thread finished; awaiting finish of 2 more threads
# ...
# 2020-08-02 00:54:38,709 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:38,709 : INFO : EPOCH - 3 : training on 44458 raw words (31397 effective words) took 0.2s, 197225 effective words/s
# 2020-08-02 00:54:38,710 : INFO : training on a 133374 raw words (94405 effective words) took 0.5s, 194499 effective words/s
# 2020-08-02 00:54:39,286 : INFO : Training batch #230
# 2020-08-02 00:54:39,287 : INFO : collecting all words and their counts
# 2020-08-02 00:54:39,287 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:39,295 : INFO : collected 4266 word types from a corpus of 45580 raw words and 100 sentences
# 2020-08-02 00:54:39,295 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:39,298 : INFO : New added 1174 unique words (21% of original 5440) and increased the count of 1174 pre-existing words (21% of original 5440)
# 2020-08-02 00:54:39,306 : INFO : deleting the raw counts dictionary of 4266 items
# 2020-08-02 00:54:39,307 : INFO : sample=0.001 downsamples 170 most-common words
# 2020-08-02 00:54:39,307 : INFO : downsampling leaves estimated 58020 word corpus (142.8% of prior 40624)
# 2020-08-02 00:54:39,320 : INFO : estimated required memory for 2348 words and 200 dimensions: 4930800 bytes
# 2020-08-02 00:54:39,321 : INFO : updating layer weights
# 2020-08-02 00:54:39,324 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:39,325 : INFO : training model with 3 workers on 8608 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:39,357 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,358 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,359 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,360 : INFO : EPOCH - 1 : training on 45580 raw words (32669 effective words) took 0.0s, 1062529 effective words/s
# 2020-08-02 00:54:39,393 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,394 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,395 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,395 : INFO : EPOCH - 2 : training on 45580 raw words (32713 effective words) took 0.0s, 1030658 effective words/s
# 2020-08-02 00:54:39,428 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,429 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,430 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,431 : INFO : EPOCH - 3 : training on 45580 raw words (32653 effective words) took 0.0s, 1065444 effective words/s
# 2020-08-02 00:54:39,431 : INFO : training on a 136740 raw words (98035 effective words) took 0.1s, 925191 effective words/s
# 2020-08-02 00:54:39,432 : INFO : collecting all words and their counts
# 2020-08-02 00:54:39,433 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:39,438 : INFO : collected 4266 word types from a corpus of 45580 raw words and 100 sentences
# 2020-08-02 00:54:39,439 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:39,442 : INFO : New added 1174 unique words (21% of original 5440) and increased the count of 1174 pre-existing words (21% of original 5440)
# 2020-08-02 00:54:39,449 : INFO : deleting the raw counts dictionary of 4266 items
# 2020-08-02 00:54:39,450 : INFO : sample=0.001 downsamples 170 most-common words
# 2020-08-02 00:54:39,451 : INFO : downsampling leaves estimated 58020 word corpus (142.8% of prior 40624)
# 2020-08-02 00:54:39,464 : INFO : estimated required memory for 2348 words and 200 dimensions: 4930800 bytes
# 2020-08-02 00:54:39,465 : INFO : updating layer weights
# 2020-08-02 00:54:39,468 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:39,469 : INFO : training model with 3 workers on 8608 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:39,581 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,583 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,584 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,585 : INFO : EPOCH - 1 : training on 45580 raw words (32801 effective words) took 0.1s, 295052 effective words/s
# 2020-08-02 00:54:39,704 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,705 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,708 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,709 : INFO : EPOCH - 2 : training on 45580 raw words (32730 effective words) took 0.1s, 273423 effective words/s
# 2020-08-02 00:54:39,823 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:39,825 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:39,827 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:39,827 : INFO : EPOCH - 3 : training on 45580 raw words (32638 effective words) took 0.1s, 284042 effective words/s
# 2020-08-02 00:54:39,828 : INFO : training on a 136740 raw words (98169 effective words) took 0.4s, 273537 effective words/s
# 2020-08-02 00:54:39,829 : INFO : collecting all words and their counts
# 2020-08-02 00:54:39,830 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:39,837 : INFO : collected 4266 word types from a corpus of 45580 raw words and 100 sentences
# 2020-08-02 00:54:39,838 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:39,842 : INFO : New added 1174 unique words (21% of original 5440) and increased the count of 1174 pre-existing words (21% of original 5440)
# 2020-08-02 00:54:39,849 : INFO : deleting the raw counts dictionary of 4266 items
# 2020-08-02 00:54:39,849 : INFO : sample=0.001 downsamples 170 most-common words
# 2020-08-02 00:54:39,850 : INFO : downsampling leaves estimated 58020 word corpus (142.8% of prior 40624)
# 2020-08-02 00:54:39,939 : INFO : estimated required memory for 8608 words, 59514 buckets and 200 dimensions: 67657880 bytes
# 2020-08-02 00:54:39,940 : INFO : updating layer weights
# 2020-08-02 00:54:40,062 : INFO : Number of new ngrams is 23
# 2020-08-02 00:54:40,107 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:40,107 : INFO : training model with 3 workers on 8608 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:40,270 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:40,274 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:40,277 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:40,278 : INFO : EPOCH - 1 : training on 45580 raw words (32776 effective words) took 0.2s, 196234 effective words/s
# 2020-08-02 00:54:40,443 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:40,446 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:40,448 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:40,448 : INFO : EPOCH - 2 : training on 45580 raw words (32583 effective words) took 0.2s, 196088 effective words/s
# 2020-08-02 00:54:40,614 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:40,616 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:40,617 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:40,618 : INFO : EPOCH - 3 : training on 45580 raw words (32811 effective words) took 0.2s, 199097 effective words/s
# 2020-08-02 00:54:40,619 : INFO : training on a 136740 raw words (98170 effective words) took 0.5s, 192238 effective words/s
# 2020-08-02 00:54:41,091 : INFO : Training batch #231
# 2020-08-02 00:54:41,092 : INFO : collecting all words and their counts
# 2020-08-02 00:54:41,093 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:41,097 : INFO : collected 3518 word types from a corpus of 27315 raw words and 60 sentences
# 2020-08-02 00:54:41,098 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:41,101 : INFO : New added 819 unique words (18% of original 4337) and increased the count of 819 pre-existing words (18% of original 4337)
# 2020-08-02 00:54:41,107 : INFO : deleting the raw counts dictionary of 3518 items
# 2020-08-02 00:54:41,108 : INFO : sample=0.001 downsamples 192 most-common words
# 2020-08-02 00:54:41,109 : INFO : downsampling leaves estimated 31499 word corpus (137.4% of prior 22918)
# 2020-08-02 00:54:41,125 : INFO : estimated required memory for 1638 words and 200 dimensions: 3439800 bytes
# 2020-08-02 00:54:41,126 : INFO : updating layer weights
# 2020-08-02 00:54:41,128 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:41,129 : INFO : training model with 3 workers on 8609 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:41,149 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,150 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,151 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,152 : INFO : EPOCH - 1 : training on 27315 raw words (19347 effective words) took 0.0s, 1040214 effective words/s
# 2020-08-02 00:54:41,174 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,175 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,176 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,177 : INFO : EPOCH - 2 : training on 27315 raw words (19318 effective words) took 0.0s, 895265 effective words/s
# 2020-08-02 00:54:41,196 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,198 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,198 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,199 : INFO : EPOCH - 3 : training on 27315 raw words (19403 effective words) took 0.0s, 1110518 effective words/s
# 2020-08-02 00:54:41,200 : INFO : training on a 81945 raw words (58068 effective words) took 0.1s, 825727 effective words/s
# 2020-08-02 00:54:41,201 : INFO : collecting all words and their counts
# 2020-08-02 00:54:41,201 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:41,205 : INFO : collected 3518 word types from a corpus of 27315 raw words and 60 sentences
# 2020-08-02 00:54:41,206 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:41,208 : INFO : New added 819 unique words (18% of original 4337) and increased the count of 819 pre-existing words (18% of original 4337)
# 2020-08-02 00:54:41,214 : INFO : deleting the raw counts dictionary of 3518 items
# 2020-08-02 00:54:41,215 : INFO : sample=0.001 downsamples 192 most-common words
# 2020-08-02 00:54:41,215 : INFO : downsampling leaves estimated 31499 word corpus (137.4% of prior 22918)
# 2020-08-02 00:54:41,228 : INFO : estimated required memory for 1638 words and 200 dimensions: 3439800 bytes
# 2020-08-02 00:54:41,230 : INFO : updating layer weights
# 2020-08-02 00:54:41,235 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:41,236 : INFO : training model with 3 workers on 8609 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:41,301 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,305 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,307 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,308 : INFO : EPOCH - 1 : training on 27315 raw words (19339 effective words) took 0.1s, 279764 effective words/s
# 2020-08-02 00:54:41,376 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,378 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,379 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,380 : INFO : EPOCH - 2 : training on 27315 raw words (19291 effective words) took 0.1s, 279492 effective words/s
# 2020-08-02 00:54:41,445 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,448 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,449 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,451 : INFO : EPOCH - 3 : training on 27315 raw words (19318 effective words) took 0.1s, 291152 effective words/s
# 2020-08-02 00:54:41,452 : INFO : training on a 81945 raw words (57948 effective words) took 0.2s, 269260 effective words/s
# 2020-08-02 00:54:41,452 : INFO : collecting all words and their counts
# 2020-08-02 00:54:41,453 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-02 00:54:41,458 : INFO : collected 3518 word types from a corpus of 27315 raw words and 60 sentences
# 2020-08-02 00:54:41,459 : INFO : Updating model with new vocabulary
# 2020-08-02 00:54:41,462 : INFO : New added 819 unique words (18% of original 4337) and increased the count of 819 pre-existing words (18% of original 4337)
# 2020-08-02 00:54:41,466 : INFO : deleting the raw counts dictionary of 3518 items
# 2020-08-02 00:54:41,467 : INFO : sample=0.001 downsamples 192 most-common words
# 2020-08-02 00:54:41,468 : INFO : downsampling leaves estimated 31499 word corpus (137.4% of prior 22918)
# 2020-08-02 00:54:41,557 : INFO : estimated required memory for 8609 words, 59531 buckets and 200 dimensions: 67673868 bytes
# 2020-08-02 00:54:41,559 : INFO : updating layer weights
# 2020-08-02 00:54:41,682 : INFO : Number of new ngrams is 17
# 2020-08-02 00:54:41,726 : WARNING : Effective 'alpha' higher than previous training cycles
# 2020-08-02 00:54:41,727 : INFO : training model with 3 workers on 8609 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-08-02 00:54:41,824 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,828 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,830 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,830 : INFO : EPOCH - 1 : training on 27315 raw words (19367 effective words) took 0.1s, 193423 effective words/s
# 2020-08-02 00:54:41,930 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:41,934 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:41,935 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:41,935 : INFO : EPOCH - 2 : training on 27315 raw words (19299 effective words) took 0.1s, 192077 effective words/s
# 2020-08-02 00:54:42,033 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-08-02 00:54:42,039 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-08-02 00:54:42,041 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-02 00:54:42,041 : INFO : EPOCH - 3 : training on 27315 raw words (19362 effective words) took 0.1s, 192013 effective words/s
# 2020-08-02 00:54:42,042 : INFO : training on a 81945 raw words (58028 effective words) took 0.3s, 184455 effective words/s
# 2020-08-02 00:54:42,410 : INFO : word2vec_076f695f38e89c1b5241c383dfe96d5e.model, word2vec_fccb3a7b2036cd74268b756c714d73be.model, fasttext_b37a2f305e0c7d956be3b60f474f13fa.model are trained in 0:07:01.238092

# %%
for c, s in zip(cbow.wv.most_similar(['engineer']), skip_gram.wv.most_similar(['engineer'])):
    print(c, s)
# Out:
# ('tester', 0.6862378120422363) ('devops', 0.5889719724655151)
# ('developer', 0.6647790670394897) ('tester', 0.5448418259620667)
# ('technician', 0.6424199342727661) ('fpga', 0.5426498651504517)
# ('programmer', 0.6294628381729126) ('opto', 0.5265384912490845)
# ('sr', 0.6243979334831238) ('atg', 0.5201519727706909)
# ('administrator', 0.6040023565292358) ('sqa', 0.5168964862823486)
# ('designer', 0.6038491725921631) ('murata', 0.5127512216567993)
# ('architect', 0.5957659482955933) ('mulesoft', 0.5110695958137512)
# ('scientist', 0.5900628566741943) ('routercim', 0.5072110891342163)
# ('analyst', 0.5836350917816162) ('algorithm', 0.5070369839668274)
# /opt/conda/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# # Train occupation classifier

# %%
onet = Onet()
onet.print_summary_stats()
# Out:
# 2020-08-02 16:41:28,196 : INFO : Manual build specified. Building O*NET CompetencyOntology via direct querying from O*NET site, or local cache.
# 2020-08-02 16:41:28,197 : INFO : Processing Content Model Reference
# 2020-08-02 16:41:29,778 : INFO : Processing occupation data
# 2020-08-02 16:41:31,138 : INFO : Processing Knowledge, Skills, Abilities
# 2020-08-02 16:42:03,946 : INFO : Processing tools and technology
# Ontology summary statistics for onet
# Num competencies: 32030
# Num occupations: 1133
# Num competency-occupation edges: 107305
# Median occupations per competency: 1
# Median competencies per occupation: 89
# Mean occupations per competency: 3.350245090386837
# Mean competencies per occupation: 94.70873786407768

# %%
class trainJobPostingParser(object):
    def __init__(self):
#         fname = '800_sample.json'
        fname = '8k_sample.json'
        f = open(fname, 'r')
        self.lines = f.read().split('\n')
        self.transformer = VirginiaTransformer(partner_id = 'VA')
        
    def __iter__(self) -> JobPostingGeneratorType:
        for line in self.lines:
            if line:
                yield self.transformer._transform(json.loads(line))

job_postings_train = trainJobPostingParser()

# %%
# target variable
full_soc = FullSOC(onet_cache=onet)

# design matrix
document_schema_fields = ['description','experienceRequirements', 'qualifications', 'skills']

dataset = itershuffle(job_postings_train)
train = islice(dataset, 0, 8000)
test =islice(dataset, 8000)

pipe_x = IterablePipeline(
    partial(nlp.fields_join, document_schema_fields=document_schema_fields),
    nlp.clean_str,
    nlp.word_tokenize,
    partial(nlp.vectorize, embedding_model=fasttext)
)

pipe_y = IterablePipeline(
    full_soc.transformer
)        


matrix = DesignMatrix(
    train, 
    full_soc,
    pipe_x,
    pipe_y,
)

# occupation classifier trainer
grid_config = {
                 'sklearn.ensemble.ExtraTreesClassifier': {
                     'n_estimators': [50, 100],
                     'criterion': ['entropy', 'gini'],
                     'max_depth': [20],
                     'max_features': ['log2'],
                     'min_samples_split': [10]
                      },
                 'sklearn.neural_network.MLPClassifier': {
                    'hidden_layer_sizes': [100, 500],
                     'activation': ['logistic', 'relu'],
                     'solver': ['adam']
                     },
                 }

cls_trainer = OccupationClassifierTrainer(
    matrix=matrix,
    k_folds=2,
    grid_config=grid_config,
    storage=FSStore('tmp/model_cache/soc_classifiers/monster'),
    n_jobs=14)

# %%
cls_trainer.train(save=False)
# Out:
# 2020-08-02 11:19:07,879 : INFO : Start training 2020-08-02T11:18:59.715516
# 2020-08-02 11:19:07,881 : INFO : Building matrix
# 2020-08-02 11:19:33,997 : INFO : total jobpostings: 8000
# 2020-08-02 11:19:33,998 : INFO : filtered jobpostings: 8000
# 2020-08-02 11:19:33,998 : INFO : dropped jobposting: 0.0
# 2020-08-02 11:19:34,010 : INFO : training ExtraTreesClassifier
# 2020-08-02 11:19:34,011 : INFO : Creating model hash from unique data {'className': 'ExtraTreesClassifier', 'parameters': {'n_estimators': [50, 100], 'criterion': ['entropy', 'gini'], 'max_depth': [20], 'max_features': ['log2'], 'min_samples_split': [10]}, 'project_path': 'tmp/model_cache/soc_classifiers/monster', 'training_metadata': {'pipe_X': ['partial(func, *args, **keywords) - new function with partial application\n    of the given arguments and keywords.\n', '\n    Args:\n        text: A unicode string\n    Returns:\n        str: lowercased, sans punctuation, non-English letters\n    ', '\n    Args:\n        text (str): a unicode string\n    Returns:\n        list: tokenized words\n    ', 'partial(func, *args, **keywords) - new function with partial application\n    of the given arguments and keywords.\n'], 'pipe_y': [None], 'target_variable': 'full_soc'}}
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 2020-08-02 11:20:17,572 : INFO : appending classifier
# 2020-08-02 11:20:17,574 : INFO : training MLPClassifier
# 2020-08-02 11:20:17,575 : INFO : Creating model hash from unique data {'className': 'MLPClassifier', 'parameters': {'hidden_layer_sizes': [100, 500], 'activation': ['logistic', 'relu'], 'solver': ['adam']}, 'project_path': 'tmp/model_cache/soc_classifiers/monster/2020-08-02T11:18:59.715516/accuracy', 'training_metadata': {'pipe_X': ['partial(func, *args, **keywords) - new function with partial application\n    of the given arguments and keywords.\n', '\n    Args:\n        text: A unicode string\n    Returns:\n        str: lowercased, sans punctuation, non-English letters\n    ', '\n    Args:\n        text (str): a unicode string\n    Returns:\n        list: tokenized words\n    ', 'partial(func, *args, **keywords) - new function with partial application\n    of the given arguments and keywords.\n'], 'pipe_y': [None], 'target_variable': 'full_soc'}}
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 2020-08-02 11:45:06,670 : INFO : appending classifier

# %%
cls_trainer.best_estimators
# Out:
# [<ProxyObjectWithStorage at 0x7fe867213830 for GridSearchCV at 0x7fe880c3d198>,
#  <ProxyObjectWithStorage at 0x7fe8672137d8 for GridSearchCV at 0x7fe880b0d208>]

# %% [markdown]
# ## Evaluations

# %%
steps = [
    partial(nlp.fields_join, document_schema_fields=document_schema_fields),
    nlp.normalize,
    nlp.clean_str,
    nlp.word_tokenize,
]

evaluators = []
test_data = list(test)
for cls in cls_trainer.best_estimators:
    tester = OccupationClassifierTester(
        test_data_generator=job_postings_train, 
        preprocessing=steps, 
        classifier=CombinedClassifier(fasttext, cls)
    )
    evaluators.append(OnetOccupationClassificationEvaluator(tester))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: generator 'itershuffle' raised StopIteration
#   if __name__ == '__main__':

# %%
for e, c in zip(evaluators, cls_trainer.best_estimators):
    print(c.best_estimator_)
    print('accuracy: ', e.accuracy)
    print('precision: ', e.precision)
    print('f1: ', e.f1)
    print('major group: ', e.accuracy_major_group)
    print('macro precision: ', e.macro_precision)
    print('micro precision: ', e.micro_precision)
    print('recall: ', e.recall)
    print('macro recall: ', e.macro_recall)
    print('micro recall: ', e.micro_recall)
    print('macro f1: ', e.macro_f1)
    print('micro f1: ', e.micro_f1)
    print('\n')
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#            max_depth=20, max_features='log2', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=14,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
# accuracy:  1.0
# precision:  [1. 1. 1. ... 1. 1. 1.]
# f1:  [1. 1. 1. ... 1. 1. 1.]
# major group:  1.0
# macro precision:  1.0
# micro precision:  1.0
# recall:  [1. 1. 1. ... 1. 1. 1.]
# macro recall:  1.0
# micro recall:  1.0
# macro f1:  1.0
# micro f1:  1.0
#
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=500, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)
# accuracy:  0.9956933677863911
# precision:  [1. 1. 1. ... 1. 1. 1.]
# f1:  [1. 1. 1. ... 1. 1. 1.]
# major group:  0.9982773471145564
# macro precision:  0.9954954954954955
# micro precision:  0.9956933677863911
# recall:  [1. 1. 1. ... 1. 1. 1.]
# macro recall:  0.996896896896897
# micro recall:  0.9956933677863911
# macro f1:  0.9959058217881746
# micro f1:  0.9956933677863911
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Generate Job posting corpus for soc prediction

# %%
monster_220k.describe()
# Out:
#                          country country_code date_added has_expired  \
# count                      22000        22000        122       22000
# unique                         1            1         77           1
# top     United States of America           US    9/22/16          No
# freq                       22000        22000          6       22000
#
#                job_board                                    job_description  \
# count              22000                                              22000
# unique                 1                                              18744
# top     jobs.monster.com  12N Horizontal Construction Engineers Job Desc...
# freq               22000                                                104
#
#        job_title   job_type    location         organization  \
# count      22000      20372       22000                15133
# unique     18749         39        8423                  738
# top      Monster  Full Time  Dallas, TX  Healthcare Services
# freq         318       6757         646                 1919
#
#                                                  page_url  \
# count                                               22000
# unique                                              22000
# top     http://jobview.monster.com/Registered-Nurse-1-...
# freq                                                    1
#
#                                 salary                     sector  \
# count                             3446                      16806
# unique                            1737                        163
# top     40,000.00 - 100,000.00 $ /year  Experienced (Non-Manager)
# freq                                50                       4594
#
#                                  uniq_id
# count                              22000
# unique                             22000
# top     89706a078c37b0f70cec1dc93cff86db
# freq                                   1

# %%
# job_postings_generator = JobPostingCollectionSample()
corpus = CorpusCreator(job_postings)
corpus_creator = SimpleCorpusCreator()
common_classifier = CombinedClassifier(fasttext, cls)
# predicted_soc = common_classifier.predict_soc(corpus_creator._transform(sample_600))

soc_list = []
for job_posting in job_postings:
    predicted_soc = common_classifier.predict_soc(corpus_creator._transform(job_posting))
    soc_list.append(predicted_soc[0][0])

# %%
len(soc_list[1160:])
# Out:
# 22000

# %% [markdown]
# # Merge with dataframe

# %%
print(monster_220k.columns)
monster_220k.head()
# Out:
# Index(['country', 'country_code', 'date_added', 'has_expired', 'job_board',
#        'job_description', 'job_title', 'job_type', 'location', 'organization',
#        'page_url', 'salary', 'sector', 'uniq_id'],
#       dtype='object')
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization  \
# 0                              NaN
# 1          Printing and Publishing
# 2  Personal and Household Services
# 3                 Altec Industries
# 4                           Retail
#
#                                             page_url salary  \
# 0  http://jobview.monster.com/it-support-technici...    NaN
# 1  http://jobview.monster.com/business-reporter-e...    NaN
# 2  http://jobview.monster.com/senior-training-lea...    NaN
# 3  http://jobview.monster.com/engineer-quality-jo...    NaN
# 4  http://jobview.monster.com/shift-supervisor-pa...    NaN
#
#                        sector                           uniq_id
# 0     IT/Software Development  11d599f229a80023d2f40e7c52cd941e
# 1                         NaN  e4cbb126dabf22159aff90223243ff2a
# 2                         NaN  839106b353877fa3d896ffb9c1fe01c0
# 3   Experienced (Non-Manager)  58435fcab804439efdcaa7ecca0fd783
# 4  Project/Program Management  64d0272dc8496abfd9523a8df63c184c

# %%
col_toDrop = ['country', 'date_added', 'has_expired', 'job_board', 'salary', 'uniq_id', 'page_url']
monster_220k.drop(col_toDrop, axis=1, inplace=True)

# %%
monster_220k['soc_code'] = soc_list[1160:]

# %%
import pickle

dirPData = ''
f_name = dirPData + 'df_output.pickle'
with open(f_name, "wb") as f:
    pickle.dump(monster_220k, f)

# %%
len(list(set(soc_list)))
# Out:
# 98

# %% [markdown]
# # Skills extraction

# %% [markdown]
# ## Reopen and parse job postings data

# %%
dirPData = '../output/'
f_name = dirPData + 'df_output.pickle'

with open(f_name, "rb") as f:
    dict_ = pickle.load(f)

monster_220k = dict_
del f_name, dict_

# %%
monster_220k.head()
# Out:
#   country_code                                    job_description  \
# 0           US  TeamSoft is seeing an IT Support Specialist to...
# 1           US  The Wisconsin State Journal is seeking a flexi...
# 2           US  Report this job About the Job DePuy Synthes Co...
# 3           US  Why Join Altec? If you’re considering a career...
# 4           US  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization                      sector    soc_code  \
# 0                              NaN     IT/Software Development  19-1099.00
# 1          Printing and Publishing                         NaN  19-1099.00
# 2  Personal and Household Services                         NaN  17-2199.05
# 3                 Altec Industries   Experienced (Non-Manager)  11-9039.00
# 4                           Retail  Project/Program Management  15-1199.00
#
#   pattern exact_match soc_match skills
# 0    None        None      None   None
# 1    None        None      None   None
# 2    None        None      None   None
# 3    None        None      None   None
# 4    None        None      None   None

# %%
fname = '../data/50_sample.json'
f = open(fname, 'r')
data = f.read().split('\n')[0]
schema = json.loads(data)
del f, data, fname

# %%
df_json = []
for i in range(monster_220k.shape[0]):
    occupation = copy.deepcopy(schema)
    occupation['hiringOrganization']['location'] = monster_220k['location'][i]
    occupation['title'] = monster_220k['job_title'][i]
    occupation['jobDescription'] = monster_220k['job_description'][i].split('\n')
    occupation['normalizedTitle']['onetCode'] = monster_220k['soc_code'][i]
    df_json.append(occupation)
    
with open("../output/monster_soc_output.json", "w") as write_file:
    for i in df_json:
        json.dump(i, write_file)
        write_file.write('\n')

# %%
## reads json data file

JobPostingType = Dict[Text, Any]
JobPostingGeneratorType = Generator[JobPostingType, None, None]
MetadataType = Dict[Text, Dict[Text, Any]]

class monsterSOCOutputParser(object):
    def __init__(self):
        fname = '../output/monster_soc_output.json'
        f = open(fname, 'r')
        self.lines = f.read().split('\n')
        self.transformer = VirginiaTransformer(partner_id = 'VA')
        
    def __iter__(self) -> JobPostingGeneratorType:
        for line in self.lines:
            if line:
                yield self.transformer._transform(json.loads(line))
    
    @property
    def metadata(self) -> MetadataType:
        return {'job postings': {
            'downloaded_from': 'jobs.monster.com',
            'month': '2020-08',
            'purpose': 'monster_analysis'
        }}
    
job_postings = monsterSOCOutputParser()

# %%
monster_220k['pattern'] = None
monster_220k['exact_match'] = None
monster_220k['soc_match'] = None
monster_220k['skills'] = None

# %%
skill_extractor_p = SkillEndingPatternExtractor(only_bulleted_lines=False)
skill_extractor_e = ExactMatchSkillExtractor(onet.competency_framework)
skill_extractor_s = SocScopedExactMatchSkillExtractor(onet)

counter = 0

for job_posting in job_postings:
    
    pattern_dict = {}   
    em_dict = {}
    soc_dict = {}
    
    skills = []
    
    for candidate_skill in skill_extractor_p.candidate_skills(job_posting):
        pattern_dict[candidate_skill.skill_name] = candidate_skill.context
        skills.append(candidate_skill.skill_name)
    monster_220k['pattern'][counter] = pattern_dict
    
    for candidate_skill in skill_extractor_e.candidate_skills(job_posting):
        em_dict[candidate_skill.skill_name] = candidate_skill.context
        skills.append(candidate_skill.skill_name)
    monster_220k['exact_match'][counter] = em_dict
    
    for candidate_skill in skill_extractor_s.candidate_skills(job_posting):
        soc_dict[candidate_skill.skill_name] = candidate_skill.context
        skills.append(candidate_skill.skill_name)
    monster_220k['soc_match'][counter] = em_dict
    
    monster_220k['skills'][counter] = list(set(skills))
    counter += 1
# Out:
# 2020-08-02 16:51:30,379 : INFO : Found 32029 entries for lookup
# 2020-08-02 16:51:31,582 : INFO : Found 32029 entries for lookup
# 2020-08-02 16:51:32,727 : INFO : Yielding candidate skill communication skills in context College degree preferred, 2 - 5 years experience in print and / or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self - motivated, team - oriented, and customer - centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients / prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,732 : INFO : Yielding candidate skill organizational skills in context College degree preferred, 2 - 5 years experience in print and / or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self - motivated, team - oriented, and customer - centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients / prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,738 : INFO : Yielding exact match <_sre.SRE_Match object; span=(18, 40), match='Call tracking software'> in string Required Skills:• Call tracking software• Phone based technical support• Problem documentation and communication• Remote Desktop Management Tools• Respond to customer requests• General understanding of LANDesk• Microsoft Office 2007 SuiteFind out why TeamSoft is the Madison area's technology leader with over 200 IT consultants.
# 2020-08-02 16:51:32,738 : INFO : Yielding exact match <_sre.SRE_Match object; span=(211, 227), match='Microsoft Office'> in string Required Skills:• Call tracking software• Phone based technical support• Problem documentation and communication• Remote Desktop Management Tools• Respond to customer requests• General understanding of LANDesk• Microsoft Office 2007 SuiteFind out why TeamSoft is the Madison area's technology leader with over 200 IT consultants.
# 2020-08-02 16:51:32,739 : INFO : Yielding exact match <_sre.SRE_Match object; span=(533, 537), match='self'> in string College degree preferred, 2-5 years experience in print and/or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client  presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self-motivated, team-oriented, and customer-centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients/prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,833 : INFO : Yielding candidate skill communication skills in context As part of your online application, please attach five samples of your work or links to five recent stories. Wisconsin State Journal, 1901 Fish Hatchery Road, Madison, WI 53713Affirmative Action / Equal Opportunity Employer / Pre - employment drug testing appliesPI94338362Apply Here College degree preferred, 2 - 5 years experience in print and / or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self - motivated, team - oriented, and customer - centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients / prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,838 : INFO : Yielding candidate skill organizational skills in context As part of your online application, please attach five samples of your work or links to five recent stories. Wisconsin State Journal, 1901 Fish Hatchery Road, Madison, WI 53713Affirmative Action / Equal Opportunity Employer / Pre - employment drug testing appliesPI94338362Apply Here College degree preferred, 2 - 5 years experience in print and / or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self - motivated, team - oriented, and customer - centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients / prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,840 : INFO : Yielding exact match <_sre.SRE_Match object; span=(204, 213), match='platforms'> in string Candidates must have strong news judgment, be well versed in business news and trends and be able to quickly prioritize coverage.At least five years’ experience reporting or editing for digital and print platforms desired.
# 2020-08-02 16:51:32,841 : INFO : Yielding exact match <_sre.SRE_Match object; span=(810, 814), match='self'> in string As part of your online application, please attach five samples of your work or links to five recent stories.Wisconsin State Journal, 1901 Fish Hatchery Road, Madison, WI 53713Affirmative Action/Equal Opportunity Employer/Pre-employment drug testing appliesPI94338362Apply Here College degree preferred, 2-5 years experience in print and/or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client  presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self-motivated, team-oriented, and customer-centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients/prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:32,986 : INFO : Yielding candidate skill coaching skills in context • Strong leadership and coaching skills are required.
# 2020-08-02 16:51:32,987 : INFO : Yielding candidate skill .• excellent communication skills in context • Demonstrated project management abilities are required .• Excellent communication skills • Proficient in Microsoft Office — Word, Excel, and PowerPoint • This position may require up to 10% travel and will be based in Raynham, MA. BE VITAL in your career.
# 2020-08-02 16:51:32,995 : INFO : Yielding candidate skill communication skills in context Inc. ( 6029) Job FunctionQuality ( Generalist) Report Previous Next {" Caption ":""," Images ":[{" Src ":" http :// images. monster. com / mm / xjjsonx / cjt1 / Carousel - 5. png "," Title ": null ," Text ": null ," Caption ": null },{" Src ":" http :// images. monster. com / mm / xjjsonx / cjt1 / Carousel - 1. png "," Title ": null ," Text ": null ," Caption ": null },{" Src ":" http :// images. monster. com / mm / xjjsonx / cjt1 / Carousel - 2. png "," Title ": null ," Text ": null ," Caption ": null },{" Src ":" http :// images. monster. com / mm / xjjsonx / cjt1 / Carousel - 3. png "," Title ": null ," Text ": null ," Caption ": null },{" Src ":" http :// images. monster. com / mm / xjjsonx / cjt1 / Carousel - 4. png "," Title ": null ," Text ": null ," Caption ": null}]} ‹ › × College degree preferred, 2 - 5 years experience in print and / or online advertising sales and be able to show consistent sales results in previous positions, Knowledge of the IT industry is preferred, Track record of creativity in sales approaches and solutions, Track record of successfully meeting and exceeding sales goals in media sales relevant to 1105 Medias line of business, Excellent client presentation and communication skills as well as strong customer service and organizational skills, The ideal candidate is energetic, self - motivated, team - oriented, and customer - centric, Understanding of how to research potential customers and use online analytics from a sales perspective, Weekly local travel to meet with clients / prospects is required, Minimal non local travel a few times a year is required
# 2020-08-02 16:51:33,001 : INFO : Yielding cand
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11659 characters</b>

# %% [markdown]
# # Save dataframe

# %%
monster_220k.head()
# Out:
#   country_code                                    job_description  \
# 0           US  TeamSoft is seeing an IT Support Specialist to...
# 1           US  The Wisconsin State Journal is seeking a flexi...
# 2           US  Report this job About the Job DePuy Synthes Co...
# 3           US  Why Join Altec? If you’re considering a career...
# 4           US  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization                      sector    soc_code  \
# 0                              NaN     IT/Software Development  19-1099.00
# 1          Printing and Publishing                         NaN  19-1099.00
# 2  Personal and Household Services                         NaN  17-2199.05
# 3                 Altec Industries   Experienced (Non-Manager)  11-9039.00
# 4                           Retail  Project/Program Management  15-1199.00
#
#                                              pattern  \
# 0  {'communication skills': 'College degree prefe...
# 1  {'communication skills': 'As part of your onli...
# 2  {'coaching skills': '• Strong leadership and c...
# 3  {'verbal communication skills': 'MAJOR RESPONS...
# 4  {'communication skills': 'College degree prefe...
#
#                                          exact_match  \
# 0  {'call tracking software': 'Required Skills:• ...
# 1  {'platforms': 'Candidates must have strong new...
# 2  {'design': 'Directs staff in the design and ad...
# 3  {'design': 'MAJOR RESPONSIBILITIES:• Learns Al...
# 4  {'self': 'College degree preferred, 2-5 years ...
#
#                                            soc_match  \
# 0  {'call tracking software': 'Required Skills:• ...
# 1  {'platforms': 'Candidates must have strong new...
# 2  {'design': 'Directs staff in the design and ad...
# 3  {'design': 'MAJOR RESPONSIBILITIES:• Learns Al...
# 4  {'self': 'College degree preferred, 2-5 years ...
#
#                                               skills
# 0  [microsoft office, organizational skills, call...
# 1  [platforms, self, organizational skills, commu...
# 2  [.• excellent communication skills, levels, co...
# 3  [rules, telecommunications, persuasion, skill,...
# 4  [self, organizational skills, communication sk...

# %%
dirPData = '../output/'
f_name = dirPData + 'df_output_skills.pickle'
with open(f_name, "wb") as f:
    pickle.dump(monster_220k, f)

# %%
# import pickle

# dirPData = ''
# f_name = dirPData + 'df_output.pickle'
# with open(f_name, "wb") as f:
#     pickle.dump(monster_220k, f)

dirPData = '../output/'
f_name = dirPData + 'df_output_skills.pickle'

with open(f_name, "rb") as f:
    dict_ = pickle.load(f)

df_output_skills = dict_
del f_name, dict_

# %%
df_output_skills.tail()
# Out:
#       country_code                                    job_description  \
# 21995           US  This is a major premier Cincinnati based finan...
# 21996           US  Luxury homebuilder in Cincinnati seeking multi...
# 21997           US  RE: Adobe AEM-          Client -          Loca...
# 21998           US  Jernberg Industries was established in 1937 an...
# 21999           US  Contract AdministratorCan you be the point per...
#
#                                                job_title            job_type  \
# 21995  Assistant Vice President - Controller Job in C...           Full Time
# 21996                       Accountant Job in Cincinnati           Full Time
# 21997                    AEM/CQ developer Job in Chicago           Full Time
# 21998  Electrician - Experienced Forging Electrician ...  Full Time Employee
# 21999           Contract Administrator Job in Cincinnati           Full Time
#
#                    location                                    organization  \
# 21995        Cincinnati, OH                                             NaN
# 21996  Cincinnati, OH 45236  Construction - Residential & Commercial/Office
# 21997     Chicago, IL 60602                                             NaN
# 21998     Chicago, IL 60609                       Jernberg Industries, Inc.
# 21999        Cincinnati, OH                                             NaN
#
#                                       sector    soc_code  \
# 21995                                    NaN  19-1099.00
# 21996  Manager (Manager/Supervisor of Staff)  43-3099.00
# 21997                                    NaN  17-2199.05
# 21998        Installation/Maintenance/Repair  19-1029.00
# 21999              Experienced (Non-Manager)  19-1029.00
#
#                                                  pattern  \
# 21995  {'strong presentation skills': 'Proven strong ...
# 21996  {'communication skills': 'College degree prefe...
# 21997  {'communication skills': 'Please send me resum...
# 21998  {'diagnostic skills': 'We are seeking qualifie...
# 21999  {'communication skills': 'College degree prefe...
#
#                                              exact_match  \
# 21995  {'monitors': 'Monitors costs and expenses, and...
# 21996  {'self': 'College degree preferred, 2-5 years ...
# 21997  {'self': 'Please send me resumes to vishakha@p...
# 21998  {'repairing': 'We are seeking qualified Candid...
# 21999  {'self': 'College degree preferred, 2-5 years ...
#
#                                                soc_match  \
# 21995  {'monitors': 'Monitors costs and expenses, and...
# 21996  {'self': 'College degree preferred, 2-5 years ...
# 21997  {'self': 'Please send me resumes to vishakha@p...
# 21998  {'repairing': 'We are seeking qualified Candid...
# 21999  {'self': 'College degree preferred, 2-5 years ...
#
#                                                   skills
# 21995  [rules, monitoring, levels, organizational ski...
# 21996  [self, organizational skills, communication sk...
# 21997  [self, organizational skills, communication sk...
# 21998  [monitoring, troubleshooting, repairing, press...
# 21999  [self, organizational skills, communication sk...
